# %%
import pandas as pd
import numpy as np
import math

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
#check Cuda
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

print(device)
# Out:
# cuda:0

# %%
#load X_train array with 'open, volume, MACD, Signal, RSI, variance, crossover' as input features
X_train=np.load('data/X_train_array.npy')  

Y_train_raw=pd.read_csv('data/Y_train.csv') #construct Y_train_array

#Modify Y_train_raw such that the length matches the length of X_train
Y_train_raw=Y_train_raw.loc[len(Y_train_raw)-X_train.shape[0]:].reset_index(drop=True)

Y_train=Y_train_raw.to_numpy()

print('shape of X_train_array:',X_train.shape)
print('shape of Y_train_array:',Y_train.shape)
# Out:
# shape of X_train_array: (13293, 120, 7)
# shape of Y_train_array: (13293, 6)

# %%
#Pick the latest 10 days for testing. There are 211 data points for each day.
n=10
data_x_train = X_train[:-211*n]
data_y_train = Y_train[:-211*n,0]
data_x_val = X_train[-211*n:]
data_y_val = Y_train[-211*n:,0]

print('shape of X_train:', data_x_train.shape)
print('shape of X_val:', data_x_val.shape)
# Out:
# shape of X_train: (11183, 120, 7)
# shape of X_val: (2110, 120, 7)

# %%
# normalization
scaler_x = StandardScaler()
scaler_y = MinMaxScaler()

data_x_train_s = scaler_x.fit_transform(data_x_train.reshape(-1,data_x_train.shape[-1])).reshape(data_x_train.shape)
data_x_val_s = scaler_x.transform(data_x_val.reshape(-1,data_x_val.shape[-1])).reshape(data_x_val.shape)
data_y_train_s = scaler_y.fit_transform(data_y_train.reshape(-1,1))
data_y_val_s = scaler_y.transform(data_y_val.reshape(-1,1))
print(data_y_val_s[:10].ravel()) #first 10 elements in data_y_val_s
# Out:
# [0.31072857 0.31351069 0.31351069 0.31657103 0.31664058 0.31664058
#  0.31664058 0.31664058 0.31664058 0.31664058]

# %%
#Dataset and Dataloader
class TimeSeriesDataset(Dataset):
    def __init__(self, x, y):
        self.x = x.astype(np.float32)
        self.y = y.astype(np.float32)

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return (self.x[idx], self.y[idx])


dataset_train = TimeSeriesDataset(data_x_train_s, data_y_train_s)
dataset_val = TimeSeriesDataset(data_x_val_s, data_y_val_s)

print("Train data shape", dataset_train.x.shape, dataset_train.y.shape)
print("Validation data shape", dataset_val.x.shape, dataset_val.y.shape)

batch_size=128

train_dl = DataLoader(dataset_train, batch_size=batch_size, shuffle=True)
val_dl = DataLoader(dataset_val, batch_size=batch_size, shuffle=True)
# Out:
# Train data shape (11183, 120, 7) (11183, 1)
# Validation data shape (2110, 120, 7) (2110, 1)

# %%
#LSTM model
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size, dropout):
        super().__init__()
        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, batch_first=True)  
        self.linear_1 = nn.Linear(num_layers * hidden_size, 32)
        self.relu = nn.ReLU()      
        self.dropout = nn.Dropout(dropout)
        self.linear_2 = nn.Linear(32, output_size)
        
    def forward(self, x):
        batchsize = x.shape[0]

        # LSTM layer
        lstm_out, (h_n, c_n) = self.lstm(x)

        # reshape output from hidden cell into [batch, features] for `linear_2`
        x = h_n.permute(1, 0, 2).reshape(batchsize, -1)  
        x = self.relu(x)
        x = self.dropout(x)
        # layer 1
        x = self.linear_1(x)
        x = self.relu(x)
        x = self.dropout(x)
        # layer 2       
        predictions = self.linear_2(x)

        return predictions


def run_epoch(dataloader, is_training=False):
    epoch_loss = 0

    if is_training:
        model.train()
    else:
        model.eval()
    
    
    for idx, (x, y) in enumerate(dataloader):
        if is_training:
            optimizer.zero_grad()

        batchsize = x.shape[0]

        x = x.to(device)
        y = y.to(device)

        out = model(x)
        loss = criterion(out.contiguous(), y.contiguous())

        if is_training:
            loss.backward()
            optimizer.step()

        epoch_loss += loss.detach().item() / math.floor(len(dataloader.dataset)/batchsize)
                       
    lr = scheduler.get_last_lr()[0]
          
    return epoch_loss, lr


model = LSTMModel(input_size=7, hidden_size=64, num_layers=2, output_size = 1, dropout=0.2)
model = model.to(device)

criterion = nn.MSELoss()


optimizer = optim.Adam(model.parameters(), lr=0.01, betas=(0.9, 0.98), eps=1e-9)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=40, gamma=0.1)

epoch_num = 80

for epoch in range(epoch_num):
    loss_train, lr_train = run_epoch(train_dl, is_training=True)
    loss_val, lr_val = run_epoch(val_dl)
    scheduler.step()

    print(f'Epoch[{epoch + 1}/{epoch_num}] | loss train:{loss_train:.6f}, test:{loss_val:.6f} | lr:{lr_train}')
# Out:
# Epoch[1/80] | loss train:0.026343, test:0.000515 | lr:0.01
# Epoch[2/80] | loss train:0.005306, test:0.000983 | lr:0.01
# Epoch[3/80] | loss train:0.005086, test:0.000870 | lr:0.01
# Epoch[4/80] | loss train:0.004805, test:0.000688 | lr:0.01
# Epoch[5/80] | loss train:0.004757, test:0.003856 | lr:0.01
# Epoch[6/80] | loss train:0.004837, test:0.000644 | lr:0.01
# Epoch[7/80] | loss train:0.004491, test:0.000906 | lr:0.01
# Epoch[8/80] | loss train:0.004776, test:0.000525 | lr:0.01
# Epoch[9/80] | loss train:0.004586, test:0.001769 | lr:0.01
# Epoch[10/80] | loss train:0.004520, test:0.000417 | lr:0.01
# Epoch[11/80] | loss train:0.004724, test:0.000620 | lr:0.01
# Epoch[12/80] | loss train:0.004458, test:0.000498 | lr:0.01
# Epoch[13/80] | loss train:0.004414, test:0.000577 | lr:0.01
# Epoch[14/80] | loss train:0.004304, test:0.001440 | lr:0.01
# Epoch[15/80] | loss train:0.004382, test:0.000854 | lr:0.01
# Epoch[16/80] | loss train:0.004228, test:0.002275 | lr:0.01
# ...

# %%
# here we re-initialize dataloader so the data doesn't shuffled, so we can plot the values by time

train_dl = DataLoader(dataset_train, batch_size=batch_size, shuffle=False)
val_dl = DataLoader(dataset_val, batch_size=batch_size, shuffle=False)

model.eval()

# predict on the training data
predicted_train = np.array([]).reshape(0, 1)

for idx, (x, y) in enumerate(train_dl):
    x = x.to(device)
    out = model(x)
    out = out.cpu().detach().numpy()
    predicted_train = np.concatenate((predicted_train, out), axis=0)

# predict on the validation data
predicted_val = np.array([]).reshape(0, 1)

for idx, (x, y) in enumerate(val_dl):
    x = x.to(device)
    out = model(x)
    out = out.cpu().detach().numpy()
    predicted_val = np.concatenate((predicted_val, out), axis=0)

# %%
#MAE and RMSE for LSTM. Here we are predicting 'High' values
lstm_mae_train = mean_absolute_error(data_y_train, scaler_y.inverse_transform(predicted_train.ravel().reshape(-1,1)).ravel())
lstm_mae_val = mean_absolute_error(data_y_val, scaler_y.inverse_transform(predicted_val.ravel().reshape(-1,1)).ravel())

print("LSTM mae train:", lstm_mae_train)
print("LSTM mae val:", lstm_mae_val)

lstm_rmse_train = np.sqrt(mean_squared_error(data_y_train, scaler_y.inverse_transform(predicted_train.ravel().reshape(-1,1)).ravel()))
lstm_rmse_val = np.sqrt(mean_squared_error(data_y_val, scaler_y.inverse_transform(predicted_val.ravel().reshape(-1,1)).ravel()))

print("LSTM rmse train:", lstm_rmse_train)
print("LSTM rmse val:", lstm_rmse_val)
# Out:
# LSTM mae train: 0.378083001467685
# LSTM mae val: 0.41788871064406197
# LSTM rmse train: 0.5346345834278435
# LSTM rmse val: 0.5994520607945192

# %%
#Draw the graph
lstm_pred=scaler_y.inverse_transform(predicted_val.ravel().reshape(-1,1)).ravel()

plt.figure(figsize=(15,8))

plt.plot(range(211*n), data_y_val,'g',label='actual')
plt.plot(range(211*n), lstm_pred,'g--',label='lstm prediction')

plt.xticks(fontsize=15)
plt.yticks(fontsize=12)
plt.legend(fontsize=14)

plt.show()

print('variance_high:',(lstm_pred-data_y_val).var(ddof=0))
# Out:
# variance_high: 0.3223647261274959

# %%
#Linear Regression
from sklearn.linear_model import LinearRegression
X_train_raw=pd.read_csv('data/X_train.csv') 
Y_train_raw=pd.read_csv('data/Y_train.csv')
n=10
length=len(X_train_raw.index)
X_train_L=X_train_raw.loc[range(0,length-211*n)]
Y_train_L=Y_train_raw.loc[range(0,length-211*n)]

X_test_L=X_train_raw.loc[range(length-211*n,length)]
Y_test_L=Y_train_raw.loc[range(length-211*n,length)]

linearh=LinearRegression().fit(X_train_L,Y_train_L['High'])
linearl=LinearRegression().fit(X_train_L,Y_train_L['Low'])
linearr=LinearRegression().fit(X_train_L,Y_train_L['return'])

linear_rmse_high=np.sqrt(mean_squared_error(linearh.predict(X_test_L),Y_test_L['High']))
linear_rmse_low=np.sqrt(mean_squared_error(linearl.predict(X_test_L),Y_test_L['Low']))
linear_rmse_r=np.sqrt(mean_squared_error(linearr.predict(X_test_L),Y_test_L['return']))

print('rmse_high:',linear_rmse_high)
print('rmse_low:',linear_rmse_low)
print('rmse_r:',linear_rmse_r)

linear_pred=linearh.predict(X_test_L)

plt.figure(figsize=(15,8))

plt.plot(range(211*n), data_y_val,'g',label='actual')
plt.plot(range(211*n), linear_pred,'g--',label='linear prediction')

plt.xticks(fontsize=15)
plt.yticks(fontsize=12)
plt.legend(fontsize=14)

plt.show()

print('variance_high:',(linearh.predict(X_test_L)-data_y_val).var(ddof=0))
# Out:
# rmse_high: 0.544827943142444
# rmse_low: 0.4792256847745018
# rmse_r: 0.7879071425099019
# variance_high: 0.29000954132994383

# %%
#Taking the average of LSTM and Linear
average_pred=(lstm_pred+linear_pred)/2
average_rmse_val = np.sqrt(mean_squared_error(data_y_val, average_pred)) 

print('average_rmse_high:',average_rmse_val)
print('variance_high:',(average_pred-data_y_val).var(ddof=0))

plt.figure(figsize=(15,8))

plt.plot(range(211*n), data_y_val,'g',label='actual')
plt.plot(range(211*n), average_pred,'g--',label='average prediction')

plt.xticks(fontsize=15)
plt.yticks(fontsize=12)
plt.legend(fontsize=14)

plt.show()
# Out:
# average_rmse_high: 0.5554187440571762
# variance_high: 0.2895936084676758
