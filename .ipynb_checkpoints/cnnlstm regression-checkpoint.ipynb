# %%
import pandas as pd
import numpy as np
import math

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from tslearn.preprocessing import TimeSeriesScalerMinMax

# %%
X_train=np.load('data/X_train_array.npy')  #load X_train array

Y_train_raw=pd.read_csv('data/Y_train.csv') #construct Y_train_array
Y_train_raw=Y_train_raw.loc[len(Y_train_raw)-X_train.shape[0]:].reset_index(drop=True)
size_y=len(Y_train_raw.index)

Y_train=np.ndarray((size_y,6))
for i in range(size_y):
    for j in range(6):
        Y_train[i,j]=Y_train_raw.loc[i][Y_train_raw.columns[j]]

print('shape of X_train_array:',X_train.shape)
print('shape of Y_train_array:',Y_train.shape)
# Out:
# shape of X_train_array: (13293, 120, 7)
# shape of Y_train_array: (13293, 6)

# %%
#Pick the latest 10 days for testing. There are 211 data points for each day.
n=10
data_x_train = X_train[:-211*n]
data_y_train = Y_train[:-211*n,0]
data_x_val = X_train[-211*n:]
data_y_val = Y_train[-211*n:,0]

print('shape of X_train:', data_x_train.shape)
print('shape of X_val:', data_x_val.shape)
# Out:
# shape of X_train: (11183, 120, 7)
# shape of X_val: (2110, 120, 7)

# %%
# normalization
scaler_x = StandardScaler()
scaler_y = MinMaxScaler()

data_x_train_s = scaler_x.fit_transform(data_x_train.reshape(-1,data_x_train.shape[-1])).reshape(data_x_train.shape)
data_x_val_s = scaler_x.transform(data_x_val.reshape(-1,data_x_val.shape[-1])).reshape(data_x_val.shape)
data_y_train_s = scaler_y.fit_transform(data_y_train.reshape(-1,1))
data_y_val_s = scaler_y.transform(data_y_val.reshape(-1,1))
print(data_y_val_s[:10].ravel()) #first 10 elements in data_y_val_s
# Out:
# [0.31072857 0.31351069 0.31351069 0.31657103 0.31664058 0.31664058
#  0.31664058 0.31664058 0.31664058 0.31664058]

# %%
#Dataset and Dataloader
class TimeSeriesDataset(Dataset):
    def __init__(self, x, y):
        self.x = x.astype(np.float32)
        self.y = y.astype(np.float32)

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return (self.x[idx], self.y[idx])


dataset_train = TimeSeriesDataset(data_x_train_s, data_y_train_s)
dataset_val = TimeSeriesDataset(data_x_val_s, data_y_val_s)

print("Train data shape", dataset_train.x.shape, dataset_train.y.shape)
print("Validation data shape", dataset_val.x.shape, dataset_val.y.shape)

batch_size=128

train_dl = DataLoader(dataset_train, batch_size=batch_size, shuffle=True)
val_dl = DataLoader(dataset_val, batch_size=batch_size, shuffle=True)
# Out:
# Train data shape (11183, 120, 7) (11183, 1)
# Validation data shape (2110, 120, 7) (2110, 1)

# %%
#check Cuda
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

print(device)
# Out:
# cuda:0

# %%
#Parallel structure of CNN and LSTM
class CNNLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(CNNLSTM, self).__init__()
        self.cnn = nn.Sequential(
            nn.Conv1d(in_channels=input_size, out_channels=64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.Dropout(0.2),
            nn.Linear(30*128,128),
            nn.BatchNorm1d(128),
            nn.ReLU()
        )
        self.fc1 = nn.Linear(input_size, hidden_size)  
        self.lstm = nn.LSTM(input_size=hidden_size, hidden_size=hidden_size, num_layers=num_layers, batch_first=True)
        self.fc_lstm = nn.Linear(hidden_size, 128)
        self.fc2 = nn.Linear(128*2, 64)
        self.fc3 = nn.Linear(64, output_size)

    def forward(self, x):
        # cnn takes input of shape (batch_size, channels, seq_len)
        x_cnn = x.permute(0, 2, 1)
        out_cnn = self.cnn(x_cnn)
        # lstm takes input of shape (batch_size, seq_len, input_size)
        x_lstm = self.fc1(x)
        out_lstm, _ = self.lstm(x_lstm)
        out_lstm = self.fc_lstm(out_lstm[:, -1, :])
        out_lstm = nn.Dropout(0.2)(out_lstm)
        out = torch.cat([out_cnn, out_lstm], dim=1)
        out = self.fc2(out)
        out = nn.Dropout(0.2)(out)
        out = self.fc3(out)
        return out

# %%
#CNN first, then LSTM
class CNN_LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(CNN_LSTM, self).__init__()
        self.cnn = nn.Sequential(
            nn.Conv1d(in_channels=input_size, out_channels=64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            
        )
        self.lstm = nn.LSTM(input_size=128, hidden_size=hidden_size, num_layers=num_layers, batch_first=True)
        self.fc_lstm = nn.Linear(hidden_size, 128)
        self.fc1 = nn.Linear(128, 64)
        self.fc2 = nn.Linear(64, output_size)

    def forward(self, x):
        #cnn takes input of shape (batch_size, channels, seq_len)
        x = x.permute(0, 2, 1)
        out = self.cnn(x)        
        # lstm takes input of shape (batch_size, seq_len, input_size)
        out = out.permute(0, 2, 1)
        out_lstm, _ = self.lstm(out)
        out = self.fc_lstm(out_lstm[:, -1, :])
        out = nn.Dropout(0.3)(out)
        out = self.fc1(out)
        out = nn.Dropout(0.3)(out)
        out = self.fc2(out)

        return out

# %%
#LSTM first, then CNN
class LSTM_CNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(LSTM_CNN, self).__init__()
        self.lstm = nn.LSTM(input_size=hidden_size, hidden_size=hidden_size, num_layers=num_layers, batch_first=True)
        self.cnn = nn.Sequential(
            nn.Conv1d(in_channels=hidden_size, out_channels=64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.Dropout(0.2),
            nn.Linear(30*128,128),
            nn.BatchNorm1d(128),
            nn.ReLU()
        )
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.lstm = nn.LSTM(input_size=hidden_size, hidden_size=hidden_size, num_layers=num_layers, batch_first=True)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, output_size)

    def forward(self, x):
        x_lstm = self.fc1(x)
        out_lstm, _ = self.lstm(x_lstm)
        out = out_lstm.permute(0, 2, 1)
        out = self.cnn(out)
        out = self.fc2(out)
        out = nn.Dropout(0.2)(out)
        out = self.fc3(out)
        return out

# %%
#Trainning
input_size=7 # we are using open, volume, MACD, Signal, RSI, variance, crossover as input features
hidden_size=128
num_layers=2
output_size=1

#Choose the model
cnnlstm=CNNLSTM(input_size, hidden_size, num_layers, output_size).to(device)
#cnn_lstm=CNN_LSTM(input_size, hidden_size, num_layers, output_size).to(device)
#lstm_cnn=LSTM_CNN(input_size, hidden_size, num_layers, output_size).to(device)

model=cnnlstm


criterion = nn.MSELoss()

optimizer = torch.optim.Adam(model.parameters(), lr=0.01, betas=(0.9, 0.98), eps=1e-9)

scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=40, gamma=0.1)

for epoch in range(100):  

    running_loss = 0.0
    for i, data in enumerate(train_dl):

        x, y = data[0].to(device), data[1].to(device)

        optimizer.zero_grad()

        outputs = model(x)
        loss = criterion(outputs.contiguous(), y.contiguous())
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        if i%10==0:
            print(f'[{epoch + 1}, {i + 1}] loss: {running_loss:.6f}')
        running_loss = 0.0
        
    scheduler.step()



print('Finished Training')
# Out:
# [1, 1] loss: 0.298601
# [1, 11] loss: 0.046766
# [1, 21] loss: 0.050738
# [1, 31] loss: 0.028176
# [1, 41] loss: 0.012711
# [1, 51] loss: 0.009563
# [1, 61] loss: 0.008937
# [1, 71] loss: 0.007246
# [1, 81] loss: 0.006464
# [2, 1] loss: 0.004406
# [2, 11] loss: 0.004929
# [2, 21] loss: 0.005045
# [2, 31] loss: 0.004528
# [2, 41] loss: 0.006236
# [2, 51] loss: 0.008965
# [2, 61] loss: 0.004412
# [2, 71] loss: 0.004120
# [2, 81] loss: 0.007943
# [3, 1] loss: 0.004432
# [3, 11] loss: 0.004580
# [3, 21] loss: 0.004196
# [3, 31] loss: 0.002687
# [3, 41] loss: 0.004737
# [3, 51] loss: 0.003359
# [3, 61] loss: 0.003066
# [3, 71] loss: 0.006941
# [3, 81] loss: 0.009729
# [4, 1] loss: 0.013764
# [4, 11] loss: 0.012272
# [4, 21] loss: 0.003607
# [4, 31] loss: 0.002563
# [4, 41] loss: 0.007265
# [4, 51] loss: 0.005989
# [4, 61] loss: 0.003594
# [4, 71] loss: 0.007871
# [4, 81] loss: 0.011757
# [5, 1] loss: 0.005963
# [5, 11] loss: 0.004185
# [5, 21] loss: 0.003673
# [5, 31] loss: 0.013979
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# here we re-initialize dataloader so the data doesn't shuffled, so we can plot the values by time

train_dl = DataLoader(dataset_train, batch_size=batch_size, shuffle=False)
val_dl = DataLoader(dataset_val, batch_size=batch_size, shuffle=False)



# predict on the training data
predicted_train = np.array([]).reshape(0, output_size)

for idx, (x, y) in enumerate(train_dl):
    x = x.to(device)
    out = model(x)
    out = out.cpu().detach().numpy()
    predicted_train = np.concatenate((predicted_train, out), axis=0)

# predict on the validation data
predicted_val = np.array([]).reshape(0, output_size)

for idx, (x, y) in enumerate(val_dl):
    x = x.to(device)
    out = model(x)
    out = out.cpu().detach().numpy()
    predicted_val = np.concatenate((predicted_val, out), axis=0)

# %%
mae_train = mean_absolute_error(data_y_train, scaler_y.inverse_transform(predicted_train.ravel().reshape(-1,1)).ravel())
mae_val = mean_absolute_error(data_y_val, scaler_y.inverse_transform(predicted_val.ravel().reshape(-1,1)).ravel())

print("MAE train:", mae_train)
print("MAE val:", mae_val)

lstm_rmsq_train = np.sqrt(mean_squared_error(data_y_train, scaler_y.inverse_transform(predicted_train.ravel().reshape(-1,1)).ravel()))
lstm_rmsq_val = np.sqrt(mean_squared_error(data_y_val, scaler_y.inverse_transform(predicted_val.ravel().reshape(-1,1)).ravel()))

print("LSTM MSQ train:", lstm_rmsq_train)
print("LSTM MSQ val:", lstm_rmsq_val)
# Out:
# MAE train: 7.8271565364202855
# MAE val: 6.464494126100494
# LSTM MSQ train: 9.623792926420059
# LSTM MSQ val: 7.700122202285034

# %%
#Draw the graph
plt.figure(figsize=(15,8))

plt.plot(range(211*n), data_y_val,'g',label='actual')
plt.plot(range(211*n), scaler_y.inverse_transform(predicted_val.ravel().reshape(-1,1)).ravel(),'g--',label='predicted')

plt.xticks(fontsize=15)
plt.yticks(fontsize=12)
plt.legend(fontsize=14)

plt.show()
